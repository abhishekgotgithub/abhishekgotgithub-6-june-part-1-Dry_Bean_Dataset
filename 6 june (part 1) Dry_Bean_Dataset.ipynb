# %% [markdown]
# source http://archive.ics.uci.edu/ml/datasets/Dry+Bean+Dataset#

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_excel('C:/Users/Admin/Desktop/daily practise/6 june/DryBeanDataset/DryBeanDataset/Dry_Bean_Dataset.xlsx')

# %%
df.head()
# Out:
#     Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0  28395    610.291       208.178117       173.888747      1.197191
# 1  28734    638.018       200.524796       182.734419      1.097356
# 2  29380    624.110       212.826130       175.931143      1.209713
# 3  30008    645.884       210.557999       182.516516      1.153638
# 4  30140    620.134       201.847882       190.279279      1.060798
#
#    Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0      0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1      0.411785       29172     191.272750  0.783968  0.984986   0.887034
# 2      0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3      0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4      0.333680       30417     195.896503  0.773098  0.990893   0.984877
#
#    Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  Class
# ...

# %%
df.shape
# Out:
# (13611, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13611 entries, 0 to 13610
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             13611 non-null  int64
#  1   Perimeter        13611 non-null  float64
#  2   MajorAxisLength  13611 non-null  float64
#  3   MinorAxisLength  13611 non-null  float64
#  4   AspectRation     13611 non-null  float64
#  5   Eccentricity     13611 non-null  float64
#  6   ConvexArea       13611 non-null  int64
#  7   EquivDiameter    13611 non-null  float64
#  8   Extent           13611 non-null  float64
#  9   Solidity         13611 non-null  float64
#  10  roundness        13611 non-null  float64
#  11  Compactness      13611 non-null  float64
#  12  ShapeFactor1     13611 non-null  float64
#  13  ShapeFactor2     13611 non-null  float64
#  14  ShapeFactor3     13611 non-null  float64
#  15  ShapeFactor4     13611 non-null  float64
# ...

# %%
df_csv= df.to_csv('DryBeanDataset.csv')

# %%
# using numpy

# %%
df_numpy=np.genfromtxt('C:/Users/Admin/DryBeanDataset.csv', delimiter=',', dtype='float')

# %%
df_numpy[2]
# Out:
# array([1.00000000e+00, 2.87340000e+04, 6.38018000e+02, 2.00524796e+02,
#        1.82734419e+02, 1.09735646e+00, 4.11785251e-01, 2.91720000e+04,
#        1.91272750e+02, 7.83968133e-01, 9.84985603e-01, 8.87033637e-01,
#        9.53860842e-01, 6.97865928e-03, 3.56362371e-03, 9.09850506e-01,
#        9.98430331e-01,            nan])

# %%
df_numpy.shape
# Out:
# (13612, 18)

# %%
type(df_numpy)
# Out:
# numpy.ndarray

# %%
def row_extaction(i):
    return np.array([row[i] for row in df_numpy ])

# %%
row_extaction(1)
# Out:
# array([   nan, 28395., 28734., ..., 42139., 42147., 42159.])

# %%
x= [(i-np.min(row_extaction(1)[1:]))/(np.max(row_extaction(1)[1:])-np.min(row_extaction(1)[1:])) for i in row_extaction(1)[1:]]

# %%
y=np.genfromtxt('C:/Users/Admin/DryBeanDataset.csv', delimiter=',', dtype='float', usecols=[1])
type(y)
# Out:
# numpy.ndarray

# %%
# normalizing the first column
(y[1:]-np.min(y[1:])) / (np.max(y[1:])-np.min(y[1:]))
# Out:
# array([0.03405267, 0.03550018, 0.03825855, ..., 0.09273856, 0.09277272,
#        0.09282396])

# %%
# finding the position of missing value in numpy array
np.where(np.isnan(df_numpy))
# Out:
# (array([    0,     0,     0, ..., 13609, 13610, 13611], dtype=int64),
#  array([ 0,  1,  2, ..., 17, 17, 17], dtype=int64))

# %%
#fingind sum of missing values
np.isnan(df_numpy).sum()
# Out:
# 13629

# %%
#here this many nan value is occuring because the dtype is float

# %%
df_=pd.read_csv('C:/Users/Admin/DryBeanDataset.csv')
df_.head()
# Out:
#    Unnamed: 0   Area  Perimeter  MajorAxisLength  MinorAxisLength  \
# 0           0  28395    610.291       208.178117       173.888747
# 1           1  28734    638.018       200.524796       182.734419
# 2           2  29380    624.110       212.826130       175.931143
# 3           3  30008    645.884       210.557999       182.516516
# 4           4  30140    620.134       201.847882       190.279279
#
#    AspectRation  Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  \
# 0      1.197191      0.549812       28715     190.141097  0.763923  0.988856
# 1      1.097356      0.411785       29172     191.272750  0.783968  0.984986
# 2      1.209713      0.562727       29690     193.410904  0.778113  0.989559
# 3      1.153638      0.498616       30724     195.467062  0.782681  0.976696
# 4      1.060798      0.333680       30417     195.896503  0.773098  0.990893
#
#    roundness  Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  \
# ...

# %%
Class=df_.groupby('Class')
Class

# %%
sns.barplot(x = 'Area',
            y = 'Class',
            data = df_)

# %%
sns.barplot(x = 'Perimeter',
            y = 'Class',
            data = df_)

# %%
for col in df_.columns:
    if  ((df_[col].dtype == np.float64) | (df_[col].dtype == np.int64)):
        sns.barplot(x=col, y='Class', data = df_)
        plt.show()
